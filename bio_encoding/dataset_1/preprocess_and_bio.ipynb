# %%
import json
from sklearn.model_selection import train_test_split

file_path = 'NER_TRAIN_JUDGEMENT.json'

# %%
import json
from sklearn.model_selection import train_test_split

# Load JSON data from file


with open(file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Extracting text and annotations
dataset = {}
for entry in data:
    case_id = entry['id']
    text = entry['data']['text']
    annotations = entry['annotations'][0]['result']

    # Create a list of tuples with start, end, and label for each entity
    entities = [(entity['value']['start'], entity['value']['end'], entity['value']['labels'][0])
                for entity in annotations]
    
    # Initialize labels list with 'O' for each token in the text
    labels = ['O'] * len(text.split())
    # print(labels)
    print(entities)
    # Assign BIO labels to tokens based on entity spans
    print(text.split())
    for start, end, label in entities:
        start_idx = len(text[:start].split())
        end_idx = len(text[:end].split())
        print(start_idx,end_idx)
        if start_idx == end_idx:
            labels[start_idx] = 'B_' + label
        else:
            labels[start_idx] = 'B_' + label
            # print(labels[start_idx + 1:end_idx+1 ])
            labels[start_idx + 1:end_idx+1 ] = ['I_' + label] * (end_idx - start_idx)


    # Store the result in the dataset dictionary
    dataset[case_id] = {'text': text, 'labels': labels}

    # break

# Printing the dataset dictionary with id, text, and labels
# Printing the dataset with span information
for case_id, values in dataset.items():
    print(f"ID: {case_id}")
    print(f"Text: {values['text']}")
    print("Labels:", values['labels'])
    
    # Print start and end positions for each token
    for token, label in zip(values['text'].split(), values['labels']):
        start = values['text'].find(token)
        end = start + len(token)
        # print(f"Token: {token}, Span: ({start}, {end}), Label: {label}")
    
    print('-' * 50)

# Split the dataset into training and validation sets
# train_dataset, val_dataset = train_test_split(list(dataset.items()), test_size=0.15, random_state=42)

# # Convert the split datasets to dictionaries
# train_dataset = dict(train_dataset)
# val_dataset = dict(val_dataset)

# # Save the datasets to separate JSON files
# with open('train_dataset.json', 'w', encoding='utf-8') as train_file:
#     json.dump(train_dataset, train_file, ensure_ascii=False, indent=2)

# with open('val_dataset.json', 'w', encoding='utf-8') as val_file:
#     json.dump(val_dataset, val_file, ensure_ascii=False, indent=2)
# Out:
# [(90, 103, 'ORG'), (267, 278, 'ORG')]
# ['(7)', 'On', 'specific', 'query', 'by', 'the', 'Bench', 'about', 'an', 'entry', 'of', 'Rs.', '1,31,37,500', 'on', 'deposit', 'side', 'of', 'Hongkong', 'Bank', 'account', 'of', 'which', 'a', 'photo', 'copy', 'is', 'appearing', 'at', 'p.', '40', 'of', "assessee's", 'paper', 'book,', 'learned', 'authorised', 'representative', 'submitted', 'that', 'it', 'was', 'related', 'to', 'loan', 'from', 'broker,', 'Rahul', '&', 'Co.', 'on', 'the', 'basis', 'of', 'his', 'submission', 'a', 'necessary', 'mark', 'is', 'put', 'by', 'us', 'on', 'that', 'photo', 'copy.']
# 17 19
# 46 49
# [(26, 30, 'OTHER_PERSON'), (101, 105, 'OTHER_PERSON'), (159, 174, 'OTHER_PERSON')]
# ['He', 'was', 'also', 'asked', 'whether', 'Agya', '<span', 'class="hidden_text"', 'id="span_5">', 'CRA', 'No.326-DB', 'of', '1998', '6</span>', 'Kaur,', 'mother-in-law', 'of', 'the', 'deceased', 'lived', 'separately', 'from', 'Tarlochan', 'Singh.']
# 5 6
# 14 15
# 22 24
# [(13, 25, 'WITNESS'), (44, 60, 'ORG'), (62, 64, 'GPE'), (121, 130, 'ORG')]
# ['5.2', 'CW3', 'Mr', 'Vijay', 'Mishra', ',', 'Deputy', 'Manager,', 'HDFC', 'Bank,', 'Noida,', 'UP', 'has', 'deposed', 'that', 'complainant', 'had', 'a', 'current', 'account', 'with', 'HDFC', 'Bank', 'in', 'the', 'year', '2004\xad2005.']
# 3 5
# 8 11
# 11 12
# 21 23
# []
# ['You', 'are', 'hereby', 'asked', 'not', 'to', 'carry', 'out', 'any', 'construction', 'work', 'of', 'the', 'said', 'building', 'hereafter', 'since', 'the', 'agreement', 'has', 'been', 'terminated".']
# [(18, 43, 'OTHER_PERSON')]
# ['The', 'pillion', 'rider', 'T.V.', 'Satyanarayana', 'Murthy', 'also', 'sustained', 'injuries.']
# 3 6
# [(119, 123, 'STATUTE')]
# [',', 'if', 'the', 'argument', 'of', 'the', 'learned', 'counsel', 'for', 'the', 'respondents', 'is', 'accepted,', 'it', 'would', 'mean', 'that', 'a', 'person', 'whose', 'bail', 'under', 'POTA', 'has', 'been', 'rejected', 'by', 'the', 'Special', 'Court', 'will', 'have', 'two', 'remedies', 'and', 'he', 'can', 'avail', 'any', 'one', 'of', 'them', 'at', 'his', 'sweet', 'will.']
# 22 23
# []
# ['After', 'all', 'the', 'steps', 'at', 'the', 'stage', 'of', 'investigation', 'has', 'to', 'be', 'reported', 'before', 'the', 'Court', 'and', 'the', 'order', 'passed', 'thereon', 'is', 'obviously', 'judicial', 'order', 'and', 'this', 'takes', 'clear', 'note', 'of', 'the', 'agony', 'of', 'the', 'learned', 'Counsels.']
# [(6, 18, 'WITNESS')]
# ['PW--2', 'Chandregowda', 'is', 'the', 'younger', 'brother', 'of', 'bi-hglllltleceased.']
# 1 2
# []
# ['What', 'is', 'the', 'main', 'offence', 'in', 'the', 'charges', 'involved', 'in', 'all', 'these', '36', 'cases?']
# [(30, 39, 'DATE')]
# ['He', 'had', 'prepared', 'G.D.', 'No.', '7', 'on', '19.8.1998', 'at', '3.05', 'A.M.']
# 7 8
# [(16, 30, 'DATE'), (32, 49, 'OTHER_PERSON')]
# ['On', 'the', 'night', 'of', '28', 'March,', '1959,', 'Krishnamurthi', 'Rao,', 'according', 'to', 'his', 'story,', 'walked', 'into', 'the', 'room', 'of', 'the', 'petitioner,', 'gave', 'the', 'bribe', 'and', 'made', 'the', 'pre-arranged', 'signal', 'which', 'brought', 'the', 'Assistant', 'Superintendent', 'of', 'Police', 'and', 'his', 'companions', 'to', 'the', 'room.']
# 4 7
# 7 9
# [(89, 97, 'OTHER_PERSON')]
# ['The', 'deceased', 'Collector', 'also', 'initiated', 'a', 'proceeding', 'under', 'the', 'Crime', 'Control', 'Order', 'against', 'Tripathi', 'and', 'inspite', 'of', 'his', 'best', 'efforts', 'bail', 'was', 'not', 'granted', 'to', 'him.']
# 13 14
# [(24, 38, 'PROVISION'), (46, 73, 'STATUTE'), (115, 140, 'ORG'), (290, 302, 'PROVISION'), (310, 331, 'STATUTE')]
# ['In', 'this', 'reference', 'under', 'Section', '66', '(1)', 'of', 'the', 'Indian', 'Income-tax', 'Act,', '1922,', 'at', 'the', 'instance', 'of', 'the', 'assessee', 'Messrs.', 'Dayabhai', '&', 'Co.', 'of', 'Barwani,', 'the', 'question', 'posed', 'for', 'our', 'answer', 'is:', '"Whether', 'on', 'the', 'facts', 'and', 'in', 'the', 'circumstances', 'of', 'this', 'case,', 'the', 'assessee', 'is', 'entitled', 'to', 'registration', 'under', 'Section', '26-A', 'of', 'the', 'Indian', 'Income-tax', 'Act', 'for', 'the', 'assessment', 'year', '1956-57?"', '2.']
# 4 7
# 9 13
# 20 25
# 50 52
# 54 57
# [(130, 139, 'DATE'), (149, 175, 'COURT'), (285, 294, 'DATE')]
# ['In', 'view', 'of', 'these', 'fact,', 'it', 'can', 'he', 'safely', 'held', 'that', 'for', 'the', 'area', 'of', 'Jaipur', 'City', '(municipal', 'limits)', 'there', 'were', 'two', 'Special', 'Judges', 'on', '29.4.1968,', 'one', 'was', 'Sessions', 'Judge', 'Jaipur', 'City,', 'who', 'by', 'virtue', 'of', 'his', 'Office', 'was', 'appointed', 'to', 'be', 'Special', 'Judge', 'for', 'that', 'area', 'by', 'virtue', 'of-Notified', 'ion', 'dated', '26.2.1968.']
# 25 26
# 28 32
# 52 53
# [(5, 16, 'OTHER_PERSON')]
# ['Shri', 'Vinay', 'Saraf,', 'learned', 'counsel', 'for', 'the', 'appellant.']
# 1 3
# [(47, 57, 'PROVISION')]
# ['The', 'other', 'section', 'involved', 'in', 'these', 'appeals', 'is', 'Section', '80', 'IB', 'which', 'provides', 'for', 'deduction', 'in', 'respect', 'of', 'profits', 'and', 'gains', 'from', 'certain', 'industrial', 'undertakings', 'other', 'than', 'infrastructure', 'development', 'undertakings.']
# 8 10
# []
# ['It', 'was', 'observed', 'that:', '"Of', 'late,', 'crime', 'against', 'women', 'in', 'general', 'and', 'rape', 'in', 'particular', 'is', 'on', 'the', 'increase.']
# [(78, 87, 'OTHER_PERSON')]
# ['The', 'torch', 'was', 'taken', 'in', 'possession', 'vide', 'memo', 'Ex.PO', 'which', 'was', 'signed', 'by', 'him', 'and', 'Nityanand,', 'besides', 'the', 'police', 'officials.']
# 15 16
# [(6, 16, 'PROVISION'), (18, 39, 'STATUTE')]
# ['Under', 'Article', '21,', 'Constitution', 'of', 'India', 'no', 'person', 'can', 'be', 'deprived', 'of', 'his', 'life', 'or', 'personal', 'liberty', 'except', 'according', '"to', 'procedure', 'established', 'bylaw".']
# 1 3
# 3 6
# []
# ['But,', 'in', 'spite', 'of', 'all,', 'the', 'efforts', 'taken', 'by', 'the', 'complainant', 'accused', 'failed', 'to', 'clear', 'the', 'outstanding', 'or', 'to', 'pay', 'the', 'total', 'amount', 'of', 'the', 'cheque', 'in', 'question.']
# [(4, 17, 'COURT'), (34, 65, 'PRECEDENT')]
# ['The', 'Supreme', 'Court,', 'in', 'the', 'case', 'of', 'Susamma', 'Thomas,', '1994', 'ACJ', '1', '(SC),', 'has', 'awarded', 'a', 'sum', 'of', 'Rs.', '15,000/-', 'each', 'on', 'the', 'above', 'two', 'heads.']
# 1 3
# 7 13
# [(104, 121, 'ORG'), (179, 196, 'ORG')]
# ['Till', 'this', 'order', 'was', 'passed,', 'the', 'selections', 'to', 'the', 'professional', 'and', 'Technical', 'Colleges', 'affiliated', 'to', 'the', 'Mysore', 'University', 'were', 'mainly', 'made', 'from', 'the', 'students', 'who', 'passed', 'out', 'of', 'the', 'Mysore', 'University.']
# 16 18
# 29 31
# []
# ['To', 'that', 'extent,', 'the', "State's", 'power', 'to', 'regulate', 'as', 'an', 'expression', 'of', 'the', 'sovereign', 'power', 'has', 'its', 'limitations.']
# []
# ['From', 'this,', 'it', 'is', 'seen', 'that', 'the', 'amounts', 'accrued', 'under', 'the', 'policy', 'are', 'even', 'not', 'only', 'kept', 'away', 'from', 'court', 'attachments', 'but', 'also', 'from', 'any', 'other', 'amounts', 'payable', 'by', 'the', 'employee', 'to', 'the', 'department.']
# [(54, 70, 'ORG'), (97, 104, 'WITNESS')]
# ['After', 'finishing', 'the', 'letter', 'PW4', 'posted', 'the', 'same', 'in', 'the', 'Edad', 'Post', 'Office', 'in', 'the', 'address', 'of', 'PW10', ',', '(Vijayan)', 'the', 'brother', 'of', 'the', 'deceased.']
# 10 13
# 20 20
# [(50, 58, 'OTHER_PERSON'), (86, 99, 'COURT')]
# ['A', 'contention', 'similar', 'to', 'the', 'one', 'now', 'raised', 'by', 'Mr.', 'Dasgupta', 'was', 'also', 'raised', 'before', 'the', 'Supreme', 'Court.']
# 10 11
# 16 18
# [(5, 15, 'DATE'), (81, 91, 'GPE')]
# ['This', '2015.07.04', '12:32', 'I', 'attest', 'to', 'the', 'accuracy', 'and', 'authenticity', 'of', 'this', 'document', 'Chandigarh', '<span', 'class="hidden_text"', 'id="span_10">', 'FAO', 'No.1042', 'of', '2003', '11</span>']
# 1 2
# 13 14
# [(4, 17, 'COURT'), (58, 71, 'OTHER_PERSON'), (76, 85, 'OTHER_PERSON')]
# ['The', 'Supreme', 'Court', 'granted', 'special', 'leave', 'to', 'appeal', 'against', 'P.N.', 'Talukdar', 'and', 'S.M.', 'Basu.']
# 1 3
# 9 11
# 12 14
# [(22, 40, 'OTHER_PERSON'), (55, 75, 'OTHER_PERSON'), (95, 116, 'OTHER_PERSON'), (135, 155, 'OTHER_PERSON'), (193, 204, 'PROVISION'), (278, 289, 'PROVISION'), (300, 311, 'PROVISION')]
# ['For', 'causing', 'injury', 'to', 'Vinubhai', 'Keshavlal', 'accused', 'No.', '2', 'Bhikhabhai', 'Nathabhai', 'and', 'accused', 'No.', '13', 'Mahadevbhai', 'Magribhai', 'and', 'accused', 'No.', '5', 'Sagrambhai', 'Nagribhai', 'would', 'be', 'liable', 'to', 'be', 'punished', 'under', 'Section', '326', 'and', 'rest', 'of', 'the', 'respondents-accused', 'would', 'be', 'liable', 'to', 'be', 'punished', 'under', 'Section', '326', 'read', 'with', 'Section', '149.']
# 4 6
# 9 11
# 15 17
# 21 23
# 30 32
# 44 46
# 48 50
# []
# ['Once', 'it', 'is', 'found', 'to', 'be', 'acceptable', 'intrinsically', 'and', 'on', 'broad', 'probabilities,', 'the', 'criticism', 'against', 'the', 'evidence', 'of', 'witnesses', 'will', 'have', 'to', 'be', 'gone', 'through', 'realistically', 'to', 'ascertain', 'whether', 'any', 'reasonable', 'doubt', 'is', 'generated', 'thereby.']
# [(3, 52, 'PRECEDENT')]
# ['In', 'United', 'India', 'Insurance', 'Co.', 'Ltd.', 'v.', 'Rajendra', 'Singh', 'this', 'Court', 'observed', 'that', '"Fraud', 'and', 'justice', 'never', 'dwell', 'together"', '(fraus', 'et', 'jus', 'nunquam', 'cohabitant)', 'and', 'it', 'is', 'a', 'pristine', 'maxim', 'which', 'has', 'never', 'lost', 'its', 'temper', 'over', 'all', 'these', 'centuries.']
# 1 9
# [(135, 164, 'PROVISION'), (172, 190, 'STATUTE'), (195, 205, 'PROVISION'), (213, 238, 'STATUTE'), (295, 308, 'COURT'), (312, 352, 'PRECEDENT')]
# ['Considering', 'the', 'evidence', 'on', 'record', 'I', 'find', 'that', 'the', 'accused', 'has', 'not', 'brought', 'any', 'credible', 'evidence', 'to', 'rebut', 'the', 'presumptions', 'provided', 'in', 'Section', '114,', 'Illustration', '(f)', 'of', 'the', 'Evidence', 'Act,', '1872', 'and', 'Section', '27', 'of', 'the', 'General', 'Clauses', 'Act,', '1897', 'and', 'further', 'looking', 'at', 'the', 'mandate', 'given', 'by', 'the', "H'onble", 'Supreme', 'Court', 'in', 'C.C.', 'Alavi', 'Hazi', 'Vs.Palapetty', 'Mohd.', '&', 'Anr']
# 22 26
# 28 31
# 32 34
# 36 40
# 50 52
# 53 60
# []
# ['He', 'proved', 'report', 'Ex.Pw19/A', 'which', 'says', 'that', 'thumb', 'impression', 'appearing', 'in', 'Ex.Pw18/A', 'and', 'Ex.Pw18/B', 'are', 'identical', 'with', 'that', 'appearing', 'in', 'FIR', 'No:', '156/04', 'State', 'v.', 'Angoori', 'Devi', 'Page', 'No.10/19', 'original', 'card', 'Ex.Pw18/E.', '11.']
# [(134, 142, 'DATE'), (164, 182, 'CASE_NUMBER'), (214, 245, 'PROVISION'), (246, 249, 'STATUTE')]
# ['To', 'complete', 'the', 'narration', 'of', 'facts', 'since', 'the', 'defendants', 'sold', 'the', 'land', 'in', 'violation', 'of', 'the', 'interim', 'injunction', 'granted', 'by', 'this', 'Court', 'on', '5-7-1990', 'the', 'plaintiffs', 'filed', 'CMA', 'No.', '6727', 'of', '93', 'to', 'punish', 'the', 'defendants', 'under', 'Order', '39', 'Rules', '2A', 'read', 'with', '151', 'CPC', 'seeking', 'detention', 'of', 'the', 'defendants', 'in', 'civil', 'prison', 'and', 'to', 'attach', 'their', 'property', 'in', 'the', 'hands', 'of', 'the', 'alienees.']
# 23 24
# 27 32
# 37 44
# 44 45
# [(111, 124, 'OTHER_PERSON'), (133, 140, 'GPE'), (142, 150, 'GPE'), (152, 159, 'GPE'), (164, 173, 'GPE'), (186, 205, 'DATE'), (238, 249, 'OTHER_PERSON'), (278, 289, 'OTHER_PERSON')]
# ['We', 'now', 'proceed', 'to', 'examine', 'the', 'evidence', 'of', 'the', 'witnesses', 'of', 'the', 'petitioner', 'who', 'were', 'produced', 'to', 'prove', 'that', 'Shri', 'Krishna', 'Kumar', 'visited', 'Lakhaya,', 'Nayagaon,', 'Rejhadi', 'and', 'Anandpura', 'villages', 'on', '21st', 'February,', '1962,', 'in', 'the', 'evening,', 'accompanied', 'by', 'Shankar', 'Lal,', 'and', 'told', 'the', 'electors', 'that', 'Shankar', 'Lal', 'would', 'take', 'them', 'to', 'the', 'polling', 'station', 'in', 'a', 'truck', 'on', 'the', 'next', 'day.']
# 20 22
# 23 24
# 24 25
# 25 26
# 27 28
# 30 33
# 38 40
# 45 47
# [(21, 41, 'COURT'), (46, 50, 'STATUTE')]
# ['There', 'was', 'no', 'regular', 'TADA', 'Court', 'at', 'Mumbai', 'and', 'TADA', "case's", 'trial', 'was', 'likely', 'to', 'take', 'some', 'time', 'to', 'commence', 'and,', 'therefore,', 'a', 'fresh', 'bail', 'application', 'was', 'filed.']
# 4 8
# 9 10
# [(13, 87, 'PRECEDENT')]
# ['Please', 'see', '-', 'State', 'of', 'Rajasthan', 'v.', 'Rajendra', 'Singh,', '(2009)', '11', 'SCC', '106:(AIR', '1998', 'SC', '2554).']
# 3 16
# [(43, 82, 'PRECEDENT')]
# ['According', 'to', 'him,', 'the', 'ratio', 'in', 'the', 'case', 'of', 'H.R.', 'Sugar', 'Factory', '(P)', 'Ltd.', '187', 'ITR', '363,', 'on', 'which', 'reliance', 'has', 'been', 'placed', 'by', 'the', 'AO', 'as', 'well', 'as', 'by', 'the', 'learned', 'CIT(A),', 'is', 'not', 'applicable', 'to', 'the', 'facts', 'of', 'this', 'case.']
# 9 17
# []
# ['The', 'Superintendent', 'of', 'Jail', 'can', 'grant', 'parole', 'upto', 'a', 'period', 'of', 'seven', 'days', 'subject', 'to', 'confirmation', 'by', 'the', 'Inspector', 'General,', 'Prisons.']
# [(96, 116, 'PROVISION'), (117, 123, 'STATUTE')]
# ['We', 'affirm', 'the', 'death', 'sentence', 'passed', 'by', 'the', 'trial', 'court', 'as', 'also', 'the', 'other', 'sentences', 'passed', 'under', 'Sections', '364', 'and', '376', 'I.P.C.', '45.']
# 17 21
# 21 22
# []
# ['During', 'the', 'raid,', '47', 'persons', 'including', 'the', 'petitioners', 'were', 'arrested,', 'several', 'documents', 'found', 'on', 'the', 'premises', 'or', 'with', 'the', 'persons', 'arrested', 'were', 'seized', 'and', 'the', 'accused', 'were', 'released', 'on', 'bail', 'by', 'the', 'police.']
# [(141, 152, 'PROVISION'), (160, 181, 'STATUTE')]
# ['While', 'dealing', 'with', 'the', 'said', 'issue,', 'this', 'Court', 'opined', 'that:-', '"It', 'is', 'settled', 'law', 'that', 'disputes', 'relating', 'to', 'contracts', 'cannot', 'be', 'agitated', 'under', 'Article', '226', 'of', 'the', 'Constitution', 'of', 'India.']
# 23 25
# 27 30
# []
# ['Even', 'assuming,', 'although', 'we', 'shall', 'presently', 'show', 'that', 'it', 'is', 'not', 'so,', 'that', 'in', 'such', 'a', 'case', 'an', 'order', 'of', 'the', 'Court', 'taking', 'cognizance', 'or', 'issuing', 'processes', 'is', 'an', 'interlocutory', 'order,', 'does', 'it', 'stand', 'to', 'reason', 'to', 'say', 'that', 'inherent', 'power', 'of', 'the', 'High', 'Court', 'cannot', 'be', 'exercised', 'for', 'stopping', 'the', 'criminal', 'proceeding', 'as', 'early', 'as', 'possible,', 'instead', 'of', 'harassing', 'the', 'accused', 'up', 'to', 'the', 'end?']
# [(92, 114, 'CASE_NUMBER')]
# ['As', 'to', 'the', 'judgment', 'relied', 'upon', 'by', 'the', 'learned', 'CIT', '(Departmental', 'Representative)', 'reported', 'in', '(1962)', '45', 'ITR', '210', '(SC)', '(supra),', 'we', 'find', 'the', 'same', 'to', 'be', 'out', 'of', 'context.']
# 14 19
# [(44, 59, 'OTHER_PERSON')]
# ['At', 'this', 'conference', 'the', "petitioner's", 'partner', 'Guidayal', 'Berlia', 'was', 'present.']
# 6 8
# []
# ['It', 'might', 'have', 'been', 'given', 'in', 'Pash-bandi."']
# [(107, 117, 'PROVISION'), (121, 140, 'STATUTE')]
# ['The', 'Arbitrators', 'set', 'out', 'several', 'reasons', 'in', 'paragraph', '7', 'of', 'the', 'original', 'award', 'in', 'support', 'of', 'their', 'view', 'that', 'section', '56', 'of', 'Indian', 'Contract', 'Act', 'was', 'not', 'attracted', 'in', 'the', 'instant', 'case.']
# 19 21
# 22 25
# [(60, 66, 'GPE')]
# ['They', 'asserted', 'that', 'the', 'lands', 'in', 'suit', 'appertained', 'to', 'village', 'Basarh', 'belonging', 'to', 'the', "'debottar'", 'estate', 'and', 'not', 'to', 'any', 'of', 'the', 'villages', 'of', 'the', 'plaintiff', 'as', 'claimed', 'in', 'the', 'plaint,', 'and', 'the', 'plaintiff', 'had', 'not', 'been', 'in', 'possession', 'of', 'that', 'disputed', 'lands', 'within', '12', 'years', 'of', 'the', 'suit,', 'the', 'possession', 'being', 'the', 'possession', 'of', 'the', 'deity.']
# 10 11
# []
# ['In', 'the', 'instant', 'case,', 'the', 'contract', 'was', 'for', 'supply', 'of', 'pouches', 'which', 'were', 'required', 'by', 'defendant', 'for', 'packaging', 'certain', 'medicines.']
# [(0, 25, 'PROVISION')]
# ['Sub-section', '(1)', 'of', 's.', '195,', 'to', 'the', 'extent', 'it', 'is', 'relevant', 'lays', 'an', 'obligation', 'on', 'any', 'person', 'on', 'securities', 'or', 'any', 'other', 'sum', 'not', 'being', 'dividends', 'chargeable', 'under', 'the', 'provisions', 'of', 'the', 'Act,', 'to', 'deduct', 'tax', 'at', 'source', 'at', 'the', 'rates', 'in', 'force.']
# 0 5
# [(69, 75, 'DATE')]
# ['He', 'was', 'again', 're-admitted', 'in', 'the', 'hospital', 'just', 'six', 'days', 'thereafter', 'on', '1.4.96', 'and', 'then', 'discharged', 'after', 'one', "week's", 'hospitalisation.']
# 12 13
# [(52, 76, 'ORG'), (94, 121, 'CASE_NUMBER')]
# ['Aggrieved', 'by', 'the', 'said', 'order,', 'Home', 'Department', 'of', 'the', 'Government', 'of', 'Tamil', 'Nadu', 'and', 'others', 'filed', 'Writ', 'Appeal', 'No.', '479', 'of', '2005.']
# 9 13
# 16 22
# [(28, 41, 'COURT')]
# ['It', 'will', 'be', 'noticed', 'that', 'the', 'Supreme', 'Court', 'did', 'not', 'altogether', 'ban', 'the', 'evolution', 'of', 'a', 'new', 'head', 'of', 'public', 'policy.']
# 6 8
# [(58, 65, 'GPE')]
# ['That', 'in', 'the', 'year', '1998,', 'a', 'massive', 'cyclone', 'hit', 'the', 'coast', 'of', 'Gujarat', 'and', 'caused', 'severe', 'damage', 'to', 'the', "appellant's", 'property,', 'machineries,', 'equipments', 'etc.', 'at', 'the', 'refinery', 'site.']
# 12 13
# [(49, 59, 'ORG')]
# ['It', 'lays', 'down', 'that', 'no', 'election', 'to', 'either', 'House', 'of', 'Parliament', 'shall', 'be', 'called', 'in', 'question', 'except', 'by', 'an', 'election', 'petition', 'presented', 'to', 'such', 'authority,', 'and', 'hi', 'such', 'manner,', 'as', 'may', 'be', 'provided', 'for,', 'by', 'or', 'under', 'any', 'law', 'made', 'by', 'the', 'appropriate', 'Legislature.']
# 10 11
# [(51, 71, 'PRECEDENT'), (97, 109, 'ORG')]
# ['Reliance', 'was', 'also', 'placed', 'on', "Tribunal's", 'decision', 'in', 'K.', 'Viswanathan', 'v.', 'CC', ',', 'which', 'was', 'relied', 'on', 'in', 'Ion', 'Exchange', '(supra).']
# 8 12
# 18 20
# [(71, 78, 'PROVISION'), (79, 86, 'STATUTE'), (106, 130, 'COURT'), (134, 144, 'DATE'), (164, 169, 'GPE'), (171, 180, 'GPE')]
# ['File', 'be', 'consigned', 'to', 'record', 'room', 'subject', 'to', 'furnishing', 'of', 'bail', 'bonds', 'u/s', '437', 'A', 'Cr.P.C.', 'Announced', 'in', 'the', 'open', '(ASHOK', 'KUMAR)', 'Court', 'on', '14.07.2014', 'MM\xad07,', 'SOUTH', 'EAST,', 'SAKET,', 'NEW', 'DELHI,', '<span', 'class="hidden_text"', 'id="span_26">FIR', 'No.', '80/11', 'Page', '26', 'of', '26</span>']
# 13 15
# 15 16
# 19 23
# 24 25
# 28 29
# 29 31
# [(34, 64, 'CASE_NUMBER')]
# ['First,', 'we', 'shall', 'take', 'the', 'facts', 'of', 'Writ', 'Petition', 'No.', '1177', 'of', '1974.']
# 7 13
# [(17, 23, 'OTHER_PERSON'), (171, 195, 'PROVISION'), (203, 218, 'STATUTE')]
# ['Therefore,', 'Shri.', 'Dharap,', 'learned', 'Counsel', 'for', 'the', 'respondent', 'submitted', 'that', 'the', 'learned', 'Single', 'Judge', 'was', 'justified', 'in', 'holding', 'that', 'there', 'is', 'an', 'unfair', 'labour', 'practice', 'under', 'item', '4(c)', 'of', 'Schedule-II', 'of', 'the', 'MRTU', '&', 'PULP', 'Act.']
# 2 3
# 26 30
# 32 36
# [(62, 72, 'PROVISION'), (81, 84, 'ORG'), (89, 92, 'STATUTE'), (127, 140, 'COURT')]
# ['From', 'this', 'major', 'premise', 'or', 'fixed', 'point', 'anchored', 'and', 'rooted', 'in', 'Section', '13', 'of', 'both', 'HMA', 'and', 'CPC,', 'the', 'exceptions', 'carved', 'out', 'by', 'the', 'Supreme', 'Court', 'would', 'need', 'to', 'be', 'examined.']
# 11 13
# 15 16
# 17 18
# 24 26
# [(81, 90, 'OTHER_PERSON'), (133, 141, 'DATE'), (172, 181, 'DATE')]
# ['In', 'paras', '7.4', 'and', '7.6,', 'the', 'learned', 'Judicial', 'Member', 'has', 'highlighted', 'as', 'to', 'how', 'Shri', 'Salauddin', 'had', 'explained', 'his', 'earlier', 'statement', 'dated', '2.3.1993', 'in', 'subsequent', 'statement', 'dated', '11.3.1993', 'with', 'reference', 'to', 'entries', 'in', 'his', 'books', 'of', 'account.']
# 15 16
# 22 23
# 27 28
# [(108, 116, 'DATE'), (127, 147, 'ORG'), (149, 154, 'GPE')]
# ['Dy.Registrar', 'was', 'competent', 'to', 'pass', 'winding', 'up', 'order', 'as', 'powers', 'were', 'delegated', 'to', 'him', 'vide', 'notification', 'dated', '18.10.77', 'issued', 'by', 'Delhi', 'Administration,', 'Delhi.']
# 17 18
# 20 22
# 22 23
# [(27, 51, 'ORG'), (79, 89, 'DATE')]
# ['Accepting', 'the', 'verdict,', 'the', 'Government', 'of', 'Tamil', 'Nadu', 'issued', 'G.O.Ms.No.139', 'dated', '25.07.2007.']
# 4 8
# 11 12
# [(18, 25, 'GPE'), (27, 40, 'OTHER_PERSON'), (146, 157, 'OTHER_PERSON'), (212, 225, 'OTHER_PERSON')]
# ['When', 'they', 'were', 'at', 'Sharjah,', 'Amna', 'Muzaffar', 'requested', 'that', 'her', 'two', 'brothers', 'also', 'be', 'called', 'there', 'and', 'get', 'them', 'employed', 'some', 'where,', 'which', 'was', 'done', 'by', 'Mohd.', 'Waqar,', 'and', 'after', 'that,', 'there', 'was', 'change', 'in', 'the', 'behaviour', 'of', 'Amna', 'Muzaffar,', 'and', 'she', 'started', 'treating', 'him', 'with', 'cruelty', 'and', 'started', 'demanding', 'divorce.']
# 4 5
# 5 7
# 26 28
# 38 40
# [(3, 68, 'PRECEDENT')]
# ['In', 'D.A.V.', 'College', 'v.', 'State', 'of', 'Punjab', 'and', 'Ors.', '[1971', '(Supp.)', 'SCR', '688],', 'the', 'question', 'posed', 'was', 'as', 'to', 'what', 'constituted', 'a', 'religious', 'or', 'linguistic', 'minority,', 'and', 'how', 'it', 'was', 'to', 'be', 'determined.']
# 1 13
# [(117, 124, 'GPE')]
# ['It', 'is', 'a', 'matter', 'of', 'record', 'that', 'the', 'representative', 'of', 'the', 'assessee', 'has', 'not', 'disproved', 'the', 'findings', 'of', 'inquiries', 'made', 'at', 'Jodhpur', 'which', 'was', 'duly', 'communicated', 'to', 'him', 'along', 'with', 'a', 'copy', 'of', 'statements', 'of', 'alleged', 'shareholders,', '"but', 'has', 'filed', 'copies', 'of', 'affidavits', 'of', 'some', 'of', 'the', 'persons', 'which', 'are', 'placed', 'on', 'records.']
# 21 22
# []
# ['Majority', 'of', 'three', 'judges,', 'dissented', 'by', 'minority', 'opinion', 'of', 'two', 'judges,', 'had', 'held', 'that', 'the', 'words', '"things', 'done"', 'in', 'para', '6', 'of', 'the', 'French', "Establishments'", '(Application', 'of', 'Laws)', 'order', 'was', 'comprehensive', 'enough', 'to', 'take', 'within', 'its', 'ambit', 'not', 'only', 'things', 'done', 'but', 'also', 'the', 'effect', 'of', 'the', 'legal', 'consequences', 'flowing', 'therefrom.']
# []
# ['This', 'aspect', 'is', 'canvassed', 'by', 'the', 'defence,', 'pointing', 'out', 'that', 'the', 'injuries', 'were', 'inflicted', 'only', 'on', 'the', 'leg', 'of', 'the', 'accused.']
# [(43, 52, 'PROVISION'), (88, 106, 'PROVISION'), (114, 135, 'STATUTE'), (194, 204, 'PROVISION'), (350, 355, 'GPE')]
# ['The', 'Challenge', 'to', 'the', 'validity', 'of', 'the', 'above', 'Clause', '13', 'of', 'the', 'Standing', 'Orders', 'is', 'based', 'on', 'Articles', '14', 'and', '16', 'of', 'the', 'Constitution', 'of', 'India', 'which', 'are', 'being', 'reproduced', 'hereunder', 'for', 'ready', 'reference:', 'Article', '14.', 'Equality', 'before', 'law:', 'The', 'State', 'shall', 'not', 'deny', 'to', 'any', 'person', 'equality', 'before', 'the', 'law', 'or', 'the', 'equal', 'protection', 'of', 'the', 'laws', 'within', 'the', 'territory', 'of', 'India.']
# 8 10
# 17 21
# 23 26
# 34 36
# 62 63
# []
# ['What', 'needs', 'to', 'be', 'adverted', 'to', 'is', 'that', 'complainant', 'is', 'to', 'be', 'examined', 'to', 'bring', 'on', 'record', '"Legal', 'Evidence",', 'and', 'not', 'just', 'to', 'have', 'the', 'evidence', 'of', '"owner', 'of', 'the', 'Negotiable', 'instrument', 'i.e.', 'cheque".']
# [(4, 39, 'PRECEDENT')]
# ['See', 'Alien', 'Berry', '&', 'Co.', 'v.', 'Union', 'of', 'India,', '.']
# 1 9
# [(52, 73, 'PROVISION')]
# ['To', 'achieve', 'this', 'aspect,', 'the', 'Legislature', 'had', 'deleted', '(b)', 'clause', 'of', 'proviso', 'with', 'an', 'intention', 'that', 'the', 'interlocutory', 'orders', 'should', 'not', 'be', 'interfered', 'with', 'in', 'the', 'revisional', 'jurisdiction', 'of', 'the', 'High', 'Court.']
# 8 12
# [(61, 107, 'PRECEDENT'), (219, 224, 'PROVISION'), (225, 231, 'STATUTE')]
# ['It', 'is', 'evident', 'that', 'the', 'drawer', 'has', 'failed', 'to', 'make', 'the', 'payment', 'CC', 'no.', '126/14', 'Bhoopindra', 'kumar', 'Vs.', 'Meenu', 'Verma', 'of', 'cheque', 'amount', 'in', 'question', 'within', '15', 'days', 'of', 'the', 'receipt', 'of', 'aforesaid', 'notice,', 'thus,', 'the', 'present', 'complaint', 'U/s', '138', 'NI', 'Act', 'has', 'been', 'initiated', 'against', 'the', 'accused.']
# 12 20
# 39 40
# 40 42
# [(22, 35, 'COURT')]
# ['The', 'question', 'that', 'the', 'Supreme', 'Court', 'posed', 'for', 'itself', 'was', 'as', 'to', 'whether', 'the', 'injustice', 'resulting', 'from', 'the', 'practice', 'of', 'discarding', 'bidis', 'and', 'not', 'making', 'any', 'payment', 'to', 'the', 'workers', 'could', 'be', 'checked,', 'controlled', 'and', 'regulated', 'by', 'the', 'issuance', 'of', 'a', 'notification.']
# 4 6
# [(29, 75, 'PRECEDENT'), (81, 91, 'COURT')]
# ['Referring', 'to', 'the', 'decision', 'in', 'D.S.NAKARA', 'Vs.', 'UNION', 'OF', 'INDIA', '(1983', '1', 'SCC', '305),', 'the', 'Apex', 'Court', 'held', 'that', 'by', 'adopting', 'the', 'principle', 'of', 'severability', 'by', 'striking', 'down', 'the', 'words', 'of', 'limitation', 'in', 'the', 'enactment,', 'the', 'provision', 'can', 'still', 'be', 'upheld.']
# 5 14
# 15 17
# [(107, 123, 'GPE'), (128, 165, 'ORG')]
# ['A', 'few', 'lines', 'occurring', 'at', 'page', '119', 'in', 'the', 'judgment', 'of', 'the', 'Privy', 'Council', 'in', 'the', 'case', 'of', 'Attorney-General', 'for', 'British', 'Columbia', 'and', 'Esquimalt', 'and', 'Nanaimo', 'Railway', 'Company', 'and', 'others', 'may', 'be', 'quoted', 'with', 'advantage.']
# 20 22
# 23 28
# []
# ['Copy', 'of', 'this', 'judgment', 'be', 'given', 'free', 'of', 'cost', 'to', 'the', 'accused', 'driver.']
# [(0, 9, 'PETITIONER'), (11, 21, 'PETITIONER'), (23, 38, 'OTHER_PERSON'), (40, 61, 'PETITIONER'), (63, 79, 'PETITIONER'), (217, 226, 'PROVISION')]
# ['Amarsingh,', 'Bhanwarial,', 'Narpat', 'Singh', 'II,', 'Jagdish', 'Prasad', 'Sharma,', 'Mohd.', 'Ahmed', 'Khan,', 'all', 'the', 'petitioners', 'are', 'admittedly', 'permanent', 'employees', 'and', 'since', 'the', 'bedrock', 'of', 'the', 'impugned', 'orders', 'of', 'termination', 'of', 'their', 'services', 'is', 'Clause', '13,', 'the', 'termination', 'orders', 'are', 'liable', 'to', 'be', 'quashed', 'and', 'are', 'hereby', 'quashed.']
# 0 1
# 1 2
# 2 5
# 5 8
# 8 11
# 32 34
# [(146, 156, 'DATE')]
# ['The', 'contention', 'of', 'the', 'petitioner', 'is', 'that', 'it', 'is', 'not', 'open', 'to', 'the', 'assessee,', 'the', 'second', 'respondent', 'herein,', 'to', 'question', 'the', 'order', 'passed', 'by', 'the', 'CIT', 'on', '01.04.2010', 'on', 'the', 'ground', 'that', 'he', 'did', 'not', 'validly', 'assume', 'jurisdiction', 'to', 'revise', 'the', 'assessment', 'orders.']
# 27 28
# [(19, 38, 'JUDGE'), (50, 72, 'CASE_NUMBER'), (76, 86, 'DATE'), (92, 118, 'PETITIONER'), (148, 156, 'GPE'), (158, 175, 'GPE')]
# ['HONBLE', 'SRI', 'JUSTICE', 'A.', 'SHANKAR', 'NARAYANA', 'MACMA', 'No.', '1808', 'of', '2005', '30-03-2015', 'The', 'National', 'Insurance', 'Company,', 'rep.', 'by', 'its', 'Branch', 'Manager,', 'Chittoor,', 'Chittoor', 'District']
# 3 6
# 6 11
# 11 12
# 13 16
# 21 22
# 22 24
# []
# ['That', 'itself', 'amounts', 'to', 'cruelty', 'by', 'filing', 'a', 'criminal', 'case.']
# []
# ['Equally', 'me', 'building', 'of', 'national', 'and', 'State', 'highways', 'involves', 'the', 'creation', 'of', 'bridges,', 'culverts,', 'etc.', 'over', 'large', 'rivers', 'or', 'smaller', 'streams,', 'which', 'vest', 'in', 'the', 'Government', 'and', 'can', 'only', 'be', 'done', 'under', 'the', 'umbrella', 'and', 'cloak', 'of', 'the', 'sovereign', 'governmental', 'powers.']
# [(36, 51, 'DATE'), (98, 106, 'GPE'), (111, 121, 'GPE'), (138, 153, 'DATE'), (190, 201, 'OTHER_PERSON'), (236, 248, 'OTHER_PERSON'), (250, 259, 'OTHER_PERSON'), (260, 271, 'OTHER_PERSON')]
# ['The', 'witness', 'further', 'deposed', 'that', 'on', '1st', 'April,', '2003', 'he', 'alongwith', 'police', 'party', 'had', 'gone', 'forests', 'at', 'Gopalpur', 'and', 'Kanchanpur', 'villages', 'and', 'on', '2nd', 'April,', '2003', 'behind', 'the', 'bushes,', 'he', 'found', 'his', 'son', 'Vikash', 'Jain', 'with', 'three', 'accused', 'persons', 'namely', 'Pradip', 'Kumar,', 'Gopal', 'and', 'Naval', 'Singh.']
# 6 9
# 17 18
# 19 20
# 23 26
# 33 35
# 40 42
# 42 44
# 44 46
# [(99, 108, 'OTHER_PERSON'), (125, 135, 'DATE')]
# ['Thereafter', 'the', 'ownership', 'of', 'property', 'in', 'which', 'tenanted', 'premises', 'is', 'situated', 'fell', 'in', 'favour', 'of', 'Smt.', 'Jeet', 'Kaur,', 'who', 'expired', 'on', '21/04/2004.']
# 16 18
# 21 22
# [(41, 51, 'DATE'), (91, 104, 'PETITIONER'), (120, 139, 'CASE_NUMBER'), (145, 160, 'PETITIONER'), (175, 200, 'CASE_NUMBER'), (216, 225, 'ORG'), (227, 237, 'OTHER_PERSON'), (253, 265, 'OTHER_PERSON')]
# ['On', 'the', 'date', 'of', 'the', 'incident,', 'that', 'is,', 'on', '05.09.2008', 'it', 'must', 'be', 'about', '8.45', 'p.m.', 'that', 'Happy', '(Tejinder', 'Bawa', '-', 'appellant', 'in', 'CRA', 'No.1046', 'of', '2011)', 'and', 'Suraj', 'Ahluwalia', '(appellant', 'in', 'CRA', 'No.', 'D-1026-DB', 'of', '2011),', 'President', 'of', 'Shiv', 'Sena,', 'Bal', 'Thakre', 'and', 'his', 'Gunman', 'Shammi', 'Kumar', 'came', 'on', 'a', 'black', 'colour', 'Bolero', 'vehicle', 'bearing', 'registration', 'No.', 'PB-10BE-4979.']
# 9 10
# 19 20
# 23 27
# 28 30
# 32 37
# 39 41
# 41 43
# 46 48
# [(51, 63, 'PROVISION')]
# ['In', 'contrast,', 'the', 'impression', 'that', 'we', 'get', 'by', 'reading', 'Section', '2(s),', 'which', 'defines', '"shared', 'household"', 'is', 'that', 'the', '"household"', 'which', 'is', 'referred', 'to', 'in', 'the', 'said', 'provision,', 'relates', 'to', 'the', 'property', 'and', 'not', 'just', 'to', 'the', 'group', 'of', 'people', 'who', 'dwell', 'under', 'the', 'same', 'roof', 'or', 'the', 'family', 'living', 'together.']
# 9 11
# [(53, 70, 'COURT')]
# ['If', 'he', 'had', 'to', 'be', 'a', 'member,', 'then', 'the', 'conclusion', 'of', 'the', 'Nagpur', 'High', 'Court', 'in', 'this', 'case', 'that', 'the', 'dispute', 'between', 'the', 'co-operative', 'bank', 'and', 'the', 'plaintiffs', 'relating', 'to', 'their', 'liability', 'which', 'arose', 'out', 'of', 'their', 'capacity', 'as', 'treasurers', 'was', 'referable', 'to', 'the', 'Registrar', 'seems', 'to', 'be', 'correct.']
# 12 15
# []
# ['Consent', 'of', 'the', 'girl', 'in', 'order', 'to', 'relieve', 'an', 'act,', 'of', 'a', 'criminal', 'character', 'like', 'rape,', 'must', 'be', 'an', 'act', 'of', 'reason,', 'accompanied', 'with', 'deliberation,', 'after', 'the', 'mind', 'has', 'weighed', 'as', 'in', 'a', 'balance,', 'the', 'good', 'and', 'evil', 'on', 'each', 'side,', 'with', 'the', 'existing', 'capacity', 'and', 'power', 'to', 'withdraw', 'the', 'assent', 'according', 'to', "one's", 'will', 'or', 'pleasure."']
# [(15, 22, 'PETITIONER'), (67, 84, 'ORG')]
# ['He', 'denied', 'that', 'Pushkar', '(appellant', 'No.4)', 'was', 'a', 'parking', 'attendant', 'in', 'Hotel', 'Le', 'Meridien', 'for', 'the', 'last', 'about', '16', 'years.']
# 3 4
# 11 14
# []
# ['Accordingly', 'in', 'June', '1970', 'a', 'dispute', 'was', 'sought', 'to', 'be', 'raised', 'before', 'the', 'District', 'Deputy', 'Registrar', '.']
# []
# ['In', 'the', 'aforesaid', 'background,', 'the', 'plea', 'raised', 'by', 'learned', 'counsel', 'for', 'petitioners', 'is', 'not', 'tenable', 'for', 'relaxation', 'of', 'qualification.']
# [(8, 23, 'JUDGE')]
# ['Justice', 'B.N.', 'Srikrishna,', 'the', 'then', 'sitting', 'Judge', 'of', 'this', 'Court', 'was', 'appointed', 'as', 'the', 'sole', 'Commissioner', 'to', 'head', 'the', 'inquiry.']
# 1 3
# [(42, 64, 'CASE_NUMBER'), (71, 88, 'DATE')]
# ['This', 'revision', 'petition', 'was', 'disposed', 'of', 'by', 'Order', 'No.', '2122', 'of', '1977', 'dated', 'December', '14,', '1977.']
# 7 12
# 13 16
# [(85, 89, 'WITNESS')]
# ['Having', 'given', 'our', 'careful', 'consideration', 'we', 'are', 'unable', 'to', 'agree', 'with', 'the', 'view', 'taken', 'by', 'Seth,', 'J.P.W.', '7']
# 15 16
# [(74, 88, 'DATE')]
# ['The', 'registration', 'certificate', 'was', 'granted', 'about', 'three', 'months', 'thereafter', 'on', '3rd', 'June,', '1966,', 'i.e.,', 'about', 'three', 'days', 'after', 'the', 'sale', 'in', 'question.']
# 10 13
# [(24, 38, 'ORG'), (55, 79, 'CASE_NUMBER')]
# ['But', 'it', 'was', 'found', 'by', 'the', 'Upa', 'Lok', 'Ayukta', 'that', 'the', 'second', 'W.P.(C).No.33916', 'of', '2008', '&', 'con.', 'Cases.']
# 6 9
# 12 15
# [(83, 93, 'PROVISION'), (101, 115, 'STATUTE')]
# ['The', 'assessee', 'further', 'contended', 'that', 'interest', 'paid', 'was', 'an', 'allowable', 'deduction', 'under', 'Section', '36', 'of', 'the', 'I.T.', 'Act,', '1961,', 'being', 'interest', 'paid', 'on', 'capital', 'borrowed', 'for', 'the', 'purpose', 'of', 'business', 'which', 'included', 'the', 'payment', 'of', 'income-tax', 'on', 'the', 'income', 'of', 'the', 'business.']
# 12 14
# 16 19
# [(15, 29, 'PETITIONER'), (45, 60, 'PETITIONER'), (117, 125, 'DATE')]
# ['The', 'petitioner', 'Uthan', 'Pada', 'Das', 'and', 'petitioner', 'Abhimunna', 'Ghosh', 'having', 'already', 'attained', 'the', 'age', 'of', '65', 'years', 'in', '1997', 'and', '31.10.96', 'respectively,', 'the', 'question', 'of', 'extension', 'of', 'their', 'services', 'does', 'not', 'arise', 'but', 'it', 'stands', 'admitted', 'that', 'during', 'their', 'extended', 'period', 'they', 'still', 'have', 'been', 'granted', 'salary', 'at', 'the', 'old', 'scale.']
# 2 5
# 7 9
# 20 21
# [(162, 167, 'GPE'), (175, 191, 'PROVISION'), (199, 213, 'STATUTE'), (312, 317, 'GPE')]
# ['The', 'question', 'arose', 'as', 'to', 'whether', 'the', 'living', 'allowances', 'and', 'salaries', 'paid', 'to', 'the', 'foreign', 'technicians', 'is', 'taxable', 'treating', 'the', 'same', 'as', 'constituting', 'salary', 'earned', 'in', 'India', 'as', 'per', 'section', '9(1)(ii)', 'of', 'the', 'Income', 'Tax', 'Act', 'as', 'it', 'stood', 'at', 'the', 'relevant', 'time', 'include', 'which', 'falls', 'under', 'the', 'head', '"Salaries"', 'if', 'it', 'is', 'earned', 'in', 'India.']
# 26 27
# 29 31
# 33 36
# 55 56
# []
# ['The', 'doctor,', 'after', 'examining', 'them', 'declared', 'both', 'dead.']
# [(24, 39, 'DATE'), (45, 89, 'ORG'), (112, 161, 'ORG'), (213, 225, 'OTHER_PERSON'), (277, 297, 'CASE_NUMBER')]
# ['On', 'the', 'same', 'date,', 'i.e.,', '19th', 'April', '1995,', 'the', 'High', 'Commission', 'of', 'the', 'Republic', 'of', 'Singapore', 'made', 'a', 'request', 'to', 'the', 'Ministry', 'of', 'External', 'Affairs,', 'Government', 'of', 'India', 'to', 'assist', 'it', 'in', 'securing', 'the', 'provisional', 'arrest', 'of', 'Rajan', 'Pillai', 'for', 'the', '<span', 'class="hidden_text"', 'id="span_5">W.P.', '(C)', 'No.', '1894', 'of', '1998', 'Page', '5', 'of', '48</span>', 'purposes', 'of', 'extradition.']
# 5 8
# 9 16
# 21 28
# 37 39
# 44 49
# [(25, 29, 'WITNESS'), (41, 45, 'WITNESS'), (68, 83, 'DATE')]
# ['The', 'statements', 'of', 'P.W.', '3', 'Anup', 'and', 'P.W.', '9', 'Ravi', 'have', 'been', 'recorded', 'on', '11st', 'June,', '2006', 'i.e.', 'two', 'days', 'after', 'the', 'incident.']
# 5 6
# 9 10
# 14 17
# [(24, 29, 'PROVISION'), (30, 37, 'STATUTE'), (54, 110, 'PRECEDENT'), (112, 122, 'COURT'), (149, 160, 'PROVISION'), (168, 191, 'STATUTE'), (245, 255, 'STATUTE')]
# ['With', 'regard', 'to', 'scope', 'of', 'S.320', 'Cr.P.C.,', 'in', 'the', 'case', 'of', 'DASAN', 'Vs.', 'STATE', 'OF', 'KERALA', 'AND', 'ANOTHER,', '(2014)', '12', 'SCC', '666,', 'Apex', 'Court', 'has', 'held', 'as', 'follows:', '"7.', 'Section', '320', 'of', 'the', 'Criminal', 'Procedure', 'Code', '(the', 'Code)', 'pertains', 'to', 'offences', 'punishable', 'under', 'the', 'Penal', 'Code', 'only.']
# 5 6
# 6 7
# 11 22
# 22 24
# 29 31
# 33 36
# 44 46
# [(25, 37, 'WITNESS')]
# ['PW-8', 'is', 'Sub', 'Inspector', 'Saudan', 'Singh,', 'who', 'is', 'I.O.', 'in', 'this', 'case.']
# 4 6
# [(162, 179, 'OTHER_PERSON'), (187, 217, 'CASE_NUMBER')]
# ['We', 'do', 'not', 'think', 'it', 'necessary', 'to', 'examine', 'several', 'other', 'decisions', 'which', 'have', 'been', 'cited,', 'and', 'we', 'would', 'merely', 'add', 'that', 'some', 'of', 'these', 'have', 'been', 'examined', 'in', 'detail', 'by', 'Balakrishna', 'Ayyar,', 'J.', 'in', 'W.', 'P.', 'Nos.', '291', 'and', '292', 'of', '1957', '(Mad).']
# 30 32
# 34 42
# [(66, 76, 'COURT'), (250, 253, 'ORG')]
# ['Under', 'this', 'circumstance,', 'in', 'paragraph', 'No.9,', 'the', 'division', 'bench', 'of', 'Apex', 'Court', 'has', 'held', 'that;', '"In', 'the', 'present', 'case,', 'admittedly,', 'no', 'notice', 'was', 'issued', 'by', 'the', 'Vth', 'Metropolitan', 'Magistrate', 'to', 'the', 'appellant', 'before', 'accepting', 'the', 'final', 'report', 'submitted', 'by', 'the', 'CBI', 'and', 'deciding', 'not', 'to', 'take', 'cognizance', 'and', 'drop', 'the', 'proceedings.']
# 10 12
# 40 41
# [(23, 43, 'OTHER_PERSON')]
# ['Therefore,', 'necessarily', 'Muthalamarappan', 'Mala', 'could', 'not', 'be', 'such', 'an', 'extensive', 'Mala.']
# 2 4
# [(44, 52, 'GPE'), (56, 73, 'DATE')]
# ['The', 'parties', 'to', 'the', 'petition', 'were', 'married', 'at', 'Sholapur', 'on', 'December', '12,', '1957.']
# 8 9
# 10 13
# []
# ['We', 'have', 'already', 'considered', 'the', 'facts', 'relating', 'to', 'bogus', 'purchase', 'invoices', 'in', 'respect', 'of', 'oil', 'cakes', 'shown', 'as', 'purchased', 'by', 'the', 'assessee', 'from', '33', 'bogus', 'suppliers.']
# []
# ['The', 'documents', 'being', 'registered', 'should', 'have', 'been', 'proved', 'through', 'the', 'concerned', 'Sub', '<span', 'class="hidden_text"', 'id="span_5">Result:', 'Application', 'dismissed', 'Page', '5', 'of', '17</span>', 'Chander', 'Kant', 'v', 'Laxmi', 'Chand', 'Ex.No.75/2010/03', 'Registrar/other', 'government', 'official/executor', 'and', 'not', 'in', 'the', 'manner', 'as', 'sought', 'to', 'be', 'proved']
# []
# ['If', 'he', 'had', 'paid', 'the', 'fine', 'amount,', 'the', 'same', 'will', 'be', 'refunded', 'to', 'him.']
# [(24, 31, 'PROVISION'), (32, 38, 'STATUTE'), (85, 97, 'RESPONDENT')]
# ['In', 'respect', 'of', 'offence', 'u/s', '3/181', 'MV', 'Act,', 'during', 'the', 'course', 'of', 'final', 'argument,', 'accused', 'Abid', '@', 'Guddu', 'admitted', 'before', 'this', 'court', 'that', 'he', 'FIR', 'No.', '196/2011,', 'State', 'Vs.', 'Abid', 'Guddu', 'was', 'driving', 'the', 'motorcycle', 'without', 'having', 'any', 'driving', 'licence,', 'as', 'alleged', 'by', 'the', 'IO/PW7', 'in', 'his', 'chief', 'examination.']
# 5 6
# 6 8
# 15 18
# [(79, 97, 'DATE'), (183, 202, 'STATUTE'), (288, 313, 'PROVISION'), (321, 333, 'STATUTE'), (363, 372, 'DATE')]
# ['It', 'was', 'contended', 'by', 'learned', 'counsel', 'that', 'an', 'order', 'was', 'made', 'by', 'the', 'President', 'on', '26th', 'January,', '1950,', 'by', 'which', 'the', 'President', 'directed', 'that', 'the', 'tax', 'on', 'sale', 'or', 'purchase', 'of', 'goods', 'under', 'the', 'U.', 'P.', 'Sales', 'Tax', 'Act', 'shall,', 'notwithstanding', 'that', 'such', 'imposition', 'of', 'tax', 'was', 'contrary', 'to', 'the', 'provisions', 'of', 'Clause', '(2)', 'of', 'Article', '286', 'of', 'the', 'Constitution,', 'continue', 'to', 'be', 'levied', 'until', '31-3-1951.']
# 15 18
# 34 39
# 52 57
# 59 60
# 65 66
# [(136, 151, 'PROVISION'), (153, 176, 'STATUTE')]
# ['For', 'all', 'that', 'each', 'accused', 'knew,', 'the', 'separate', 'blows', 'he', 'dealt', 'were', 'alleged', 'in', 'the', 'charge', 'to', 'he', 'the', 'fatal', 'ones,', 'because', 'that', 'is', 'implied', 'by', 'Section', '221', '(5),', 'Criminal', 'Procedure', 'Code,', 'But', 'the', 'fact', 'was', 'that', 'although', 'the', 'deceased', 'had', '22', 'items', 'of', 'injuries,', 'only', '3', 'on', 'the', 'head', 'were', 'grievous', 'and', 'the', 'remaining', '10', 'were', 'simple', 'i.e.,', 'did', 'not', 'even', 'endanger', 'life.']
# 26 29
# 29 32
# []
# ['and', 'was', 'chased', 'by', 'the', 'public,', 'but', 'he', 'escaped.']
# [(64, 77, 'GPE'), (132, 145, 'GPE'), (177, 182, 'GPE')]
# ['The', 'object', 'was', 'to', 'verify', 'claims', 'of', 'these', 'displaced', 'persons', 'from', 'West', 'Pakistan', 'in', 'respect', 'of', 'their', 'properties', 'left', 'behind', 'by', 'them', 'in', 'West', 'Pakistan', 'at', 'the', 'time', 'of', 'their', 'return', 'to', 'India.']
# 11 13
# 23 25
# 32 33
# [(73, 80, 'PETITIONER'), (107, 112, 'WITNESS'), (136, 143, 'WITNESS')]
# ['The', 'oral', 'evidence', 'on', 'this', 'point', 'I', 'consists', 'of', 'the', 'deposition', 'of', 'claimant', 'Jagalia,', 'Ex,', '38,', 'that', 'of', 'claimant', 'Ditia,', 'Ex.', '39', 'and', 'the', 'driver', 'Shabhai,', 'Ex.', '44.']
# 13 14
# 19 20
# 25 26
# [(19, 29, 'PROVISION')]
# ['If', 'it', 'is', 'not,', 'then', 'Section', '22', 'was', 'no', 'bar', 'to', 'the', 'maintainability', 'of', 'the', 'suit.']
# 5 7
# []
# ['The', 'said', 'Yogas', 'arc', 'not', 'merely', 'thcorization', 'in', 'the', 'metaphysical', 'spheres', 'but', 'have', 'a', 'tremendous', 'bearing', 'in', 'the', 'pragmatic', 'world.']
# []
# ['Accordingly,', 'we', 'reverse', 'the', 'order', 'of', 'the', 'Tribunal', 'in', 'both', 'the', 'cases', 'on', 'this', 'point.']
# [(70, 109, 'ORG'), (111, 120, 'GPE')]
# ['Rs.', '10', 'lacs', 'for', 'a', 'period', 'of', '6', 'years', 'Deposition', 'of', 'awarded', 'amount', 'with', 'STATE', 'BANK', 'OF', 'INDIA,', 'Saket', 'Court', 'Branch,', 'New', 'Delhi.']
# 14 21
# 21 23
# [(100, 104, 'GPE'), (108, 114, 'GPE')]
# ['In', 'such', 'an', 'event', 'also', 'there', 'was', 'no', 'occasion', 'for', 'the', 'plaintiffs', 'to', 'rebook', 'the', 'said', 'consignments', 'from', 'Gaya', 'to', 'Ranchi', 'under', 'fresh', 'consignments', 'notes.']
# 18 19
# 20 21
# []
# ['Where', 'a', 'defendant', 'denies', 'an', 'allegation', 'of', 'fact', 'in', 'the', 'plaint,', 'he', 'must', 'not', 'do', 'so', 'evasively,', 'but', 'answer', 'the', 'point', 'of', 'substance.']
# [(15, 89, 'PRECEDENT')]
# ['As', 'was', 'said', 'in', 'State', 'of', 'Rajasthan', 'v.', 'S.', 'Chawla,', '(1959)', 'Supp', '1', 'SCR', '904', '=', '(AIR', '1959', 'SC', '544)', 'the', 'entries', 'in', 'the', 'lists', 'must', 'be', 'regarded', 'as', 'enumeratio', 'simplex', 'of', 'broad', 'categories.']
# 4 20
# [(83, 92, 'OTHER_PERSON'), (96, 114, 'CASE_NUMBER')]
# ['However,', 'it', 'is', 'always', 'necessary', 'to', 'remember', 'in', 'that', 'connection', 'the', 'observations', 'of', 'Parke,', 'B.', 'in', '(1834)', '149', 'ER', '1044', 'already', 'referred', 'to', 'which', 'not', 'only', 'define', 'what', 'a', 'privileged', 'occasion', 'is', 'but', 'also', 'the', 'principle', 'on', 'which', 'it', 'is', 'based.']
# 13 15
# 16 20
# []
# ['Merely', 'because', 'the', 'stone', 'slab', 'was', 'not', 'plastered,', 'the', 'evidence', 'regarding', 'recovery', 'cannot', 'be', 'doubted.']
# [(27, 42, 'WITNESS'), (81, 90, 'OTHER_PERSON')]
# ['The', 'Investigating', 'Officer,', 'Himatgiri', 'Gosai,', 'was', 'examined', 'and', 'police', 'statement', 'of', 'Laljibhai', 'was', 'duly', 'proved', 'through', 'his', 'evidence.']
# 3 5
# 11 12
# []
# ['The', 'court', 'mentions', 'that', 'accordingly', 'it', 'recorded', 'first', 'answer', 'given', 'by', 'the', 'witness.']
# []
# ['It', 'has', 'been', 'submitted', 'that', 'the', 'those', 'witnesses', 'were', 'none', 'else', 'but', 'accomplices', 'and', 'were', 'induced', 'by', 'Navy', 'by', 'continuously', 'placing', 'the', 'orders', 'on', 'them', 'despite', 'discovery', 'of', 'story', 'of', 'so-called', 'illegal', 'gratifications', 'allegedly', 'paid', 'by', 'them', 'to', 'the', 'petitioner.']
# []
# ['Apart', 'from', 'the', 'compensation', 'for', 'acquisition', 'of', 'the', 'said', 'premises,', 'the', 'assessee', 'received', 'a', 'sum', 'of', 'Rs.', '2', 'lakhs', 'from', 'the', 'State', 'on', 'account', 'of', 'mesne', 'profits', 'for', 'the', 'use', 'and', 'occupation', 'of', 'the', 'said', 'premises', 'by', 'the', 'erstwhile', 'tenant.']
# [(6, 20, 'PROVISION'), (58, 90, 'STATUTE')]
# ['21.', 'Section', '173(8)', 'is', 'a', 'new', 'provision', 'introduced', 'by', 'the', 'Code', 'of', 'Criminal', 'Procedure,', '1973', '(hereinafter', 'referred', 'to', 'as', '„Code‟),', 'which', 'was', 'not', 'there', 'in', 'the', 'earlier', 'Code.']
# 1 3
# 10 15
# [(36, 45, 'DATE'), (100, 110, 'DATE'), (114, 131, 'CASE_NUMBER'), (142, 191, 'PRECEDENT')]
# ['The', 'petitioner', 'was', 'also', 'examined', 'on', '28.4.2014', 'in', 'terms', 'of', 'the', 'judgment', 'of', 'the', "Hon'ble", 'High', 'Court', 'on', '11.01.2013', 'in', 'MACA', 'NO.', '792/2006', 'titled', 'as', 'Oriental', 'Insurance', 'Co.', 'Ltd', 'v.', 'Ranjit', 'Pandey', '&', 'Ors.']
# 6 7
# 18 19
# 20 23
# 25 34
# []
# ['The', 'plaintiff', 'has', 'to', 'allege', 'and', 'prove', 'that', 'all', 'the', 'terms', 'of', 'the', 'contract', 'are', 'not', 'contained', 'in', 'the', 'promissory', 'note.']
# []
# ['What', 'the', 'notification', 'has', 'in', 'view', 'is', 'not', 'a', 'hospital', 'who', 'pampers', 'those', 'in', 'high', 'places', 'but', 'one', 'who', 'gives', 'free', 'treatment', 'to', 'those', 'who', 'find', 'it', 'difficult', 'to', 'survive', 'let', 'alone', 'afford', 'the', 'luxury', 'of', 'being', 'treated', 'in', 'a', 'private', 'hospital.']
# []
# ['The', 'trial', 'Court', 'ordered', 'the', 'petition', 'and', 'directed', 'the', '3rd', 'defendant', 'to', 'pay', 'the', 'stamp', 'duty', 'and', 'penalty', 'on', 'Ex.B38,', 'and', 'challenging', 'the', 'said', 'order,', 'a', 'revision', 'was', 'filed', 'in', 'this', 'Court.']
# [(20, 43, 'WITNESS')]
# ['However,', 'when', 'P.W.2', 'Rajesh', 'Kumar', 'Srivastava', 'was', 'examined', 'in', 'court,', 'he', 'has', 'not', 'stated', 'a', 'word', 'about', 'receipt', 'of', 'any', 'secret', 'information', 'by', 'him.']
# 3 6
# [(39, 59, 'STATUTE'), (65, 89, 'STATUTE'), (95, 107, 'STATUTE')]
# ['There', 'is', 'no', 'reason', 'to', 'suppose', 'that', 'the', 'Civil', 'Procedure', 'Code,', 'the', 'Transfer', 'of', 'Property', 'Act,', 'the', 'Contract', 'Act', 'are', 'excluded', 'from', 'this', 'overriding', 'effect', 'given', 'to', 'these', 'laws.']
# 8 11
# 12 16
# 17 19
# []
# ['The', 'Returning', 'Officer', 'could', 'not', 'have', 'been', 'unaware', 'of', 'the', 'fact', 'that', 'the', 'respondent', 'was', 'getting', 'a', 'second', 'application', 'for', 'recount', 'written', 'and', 'he', 'was', 'duty', 'bound', 'to', 'enable', 'him', 'to', 'complete', 'it', 'and', 'present', 'it.']
# [(95, 103, 'DATE'), (133, 141, 'DATE'), (169, 256, 'STATUTE'), (274, 282, 'DATE')]
# ['The', 'tax', 'in', 'respect', 'of', 'contract', 'carriages', '(omni', 'buses)', 'increased', 'to', 'Rs.1,000/-', 'with', 'effect', 'from', '1.4.1994;', 'Rs.1,500/-', 'with', 'effect', 'from', '1.4.1996', 'and', 'again', 'to', 'Rs.2,000/-', 'by', 'Tamil', 'Nadu', 'Motor', 'Vehicles', 'Taxation', '(Amendment)', 'Act,', '1998', '(Tamil', 'Nadu', 'Act', 'No.27', 'of', '1998)', 'with', 'effect', 'from', '1.7.1998.']
# 15 16
# 20 21
# 26 40
# 43 44
# [(28, 57, 'PROVISION'), (65, 74, 'STATUTE')]
# ['By', 'reason', 'of', 'the', 'proviso', 'to', 'Sub-section', '(1)', 'of', 'Section', '10', 'of', 'the', 'Nayar', 'Act,', 'the', 'father', 'is', 'not', 'the', 'guardian', 'of', 'his', 'minor', 'children', 'in', 'respect', 'of', 'their', 'tarwad', 'property.']
# 6 11
# 13 15
# [(29, 50, 'CASE_NUMBER'), (55, 67, 'OTHER_PERSON'), (99, 109, 'DATE'), (152, 162, 'DATE'), (170, 194, 'COURT')]
# ['ii.', 'The', 'bail', 'application', '(M.Cr.C.', 'No.10417/2010)', 'of', 'Satish', 'Lodhi', 'was', 'dismissed', 'by', 'this', 'Court', 'on', '26.11.2010,', 'copy', 'thereof', 'was', 'sent', 'by', 'the', 'Registry', 'on', '31.12.2010', 'to', 'the', 'Sessions', 'Judge,', 'Jabalpur.']
# 5 6
# 7 9
# 15 16
# 24 25
# 27 30
# [(56, 67, 'PROVISION'), (75, 92, 'STATUTE'), (102, 112, 'PETITIONER'), (133, 144, 'PROVISION'), (155, 165, 'PROVISION'), (173, 190, 'STATUTE'), (200, 208, 'PETITIONER'), (213, 221, 'PETITIONER')]
# ['After', 'the', 'case', 'was', 'received', 'by', 'commitment,', 'charge', 'under', 'Section', '302', 'of', 'the', 'Indian', 'Penal', 'Code,', 'against', 'Bhup', 'Singh,', 'accused,', 'and', 'under', 'Section', '302', 'read', 'with', 'Section', '34', 'of', 'the', 'Indian', 'Penal', 'Code,', 'against', 'Omeshwar', 'and', 'Mahender,', 'accused,', 'was', 'framed,', 'to', 'which', 'they', 'pleaded', 'not', 'guilty,', 'and', 'claimed', 'judicial', 'trial.']
# 9 11
# 13 16
# 17 19
# 22 24
# 26 28
# 30 33
# 34 35
# 36 37
# [(0, 45, 'CASE_NUMBER'), (186, 197, 'PROVISION'), (208, 230, 'PROVISION'), (231, 234, 'STATUTE')]
# ...
# ['Special', 'Civil', 'Application', 'Nos.', '11146', 'of', '1994', 'and', '11147', 'of', '1994', 'are', 'also', 'filed', 'by', 'the', 'petitioners', 'who', 'are', 'also', 'the', 'Advocates', 'practicing', 'in', 'Labour', 'Court', 'at', 'Rajkot.']
# 0 11
# 24 28
# [(153, 166, 'COURT'), (170, 233, 'PRECEDENT')]
# ['A', 'cryptic', 'anonymous', 'oral', 'message', 'which', 'did', 'not', 'in', 'terms', 'clearly', 'specify', 'cognizable', 'offence,', 'cannot', 'be', 'treated', 'as', 'First', 'Information', 'Report', 'as', 'held', 'by', 'the', 'Supreme', 'Court', 'in', 'Tapinder', 'Singh', 'v.', 'State', 'of', 'Punjab,', 'reported', 'in', '1970', '(2)', 'SCC', '113.']
# 25 27
# 28 40
# []
# ['Then', 'comes', 'the', 'question', 'whether', 'even', 'assuming', 'that', 'the', 'matters', 'raised', 'in', 'the', 'suit', 'are', 'arbitrable', 'the', 'discretion', 'of', 'the', 'Court', 'should', 'be', 'exercised', 'against', 'the', 'stay', 'of', 'the', 'suit.']
# [(124, 137, 'PROVISION')]
# ['The', 'position,', 'therefore,', 'was', 'that', 'for', 'the', "petitioner's", 'service,', 'the', 'timings', 'were', 'regulated', 'by', 'the', 'concerned', 'authority', 'under', 'Section', '48(c)', 'by', 'the', 'preparation', 'of', 'a', 'time', 'table', 'for', 'that', 'purpose.']
# 18 20
# [(165, 175, 'COURT'), (240, 290, 'CASE_NUMBER'), (291, 310, 'OTHER_PERSON')]
# ['Therefore,', 'this', 'Court', 'finds', 'no', 'reason', 'to', 'adopt', 'a', 'different', 'formula', 'for', 'the', 'victim', 'who', 'is', 'above', "'15'", 'of', 'age,', 'whereas', 'the', 'relevant', 'factors', 'have', 'been', 'adopted', 'by', 'the', 'Apex', 'Court', 'such', 'as', '(i)', 'age', 'of', 'the', 'deceased', '(ii)', 'income', 'of', 'the', 'deceased', 'and', 'Petition', 'No.', ':', '309/13', 'and', '310/13', 'Page', 'No.', '19', 'of', '27', 'Anand', 'Prakash', 'Tamta', '&', 'Ors.']
# 29 31
# 44 55
# 55 58
# []
# ['Contents', 'of', 'the', 'application', 'were', 'denied', 'and', 'it', 'was', 'prayed', 'that', 'the', 'application', 'be', 'dismissed.']
# [(160, 170, 'PROVISION')]
# ['On', 'the', 'other', 'hand,', 'however', 'speculative', 'the', 'transaction', 'might', 'be,', 'if', 'there', 'is', 'delivery,', 'it', 'cannot', 'be', 'considered', 'as', 'a', 'speculative', 'transaction', 'for', 'the', 'purposes', 'of', 'Section', '24."', '9.']
# 26 28
# []
# ['The', 'petitioners', 'have', 'directed', 'their', 'attack', 'not', 'only', 'against', 'these', 'two', 'notifications', 'Ex.', '2', 'and', 'Ex.', '3', 'but', 'also', 'against', 'the', 'reservations', 'made', 'in', 'the', 'Prospectus', 'in', 'respect', 'of', 'certain', 'categories.']
# [(59, 69, 'DATE'), (96, 111, 'OTHER_PERSON'), (117, 130, 'OTHER_PERSON'), (143, 153, 'OTHER_PERSON'), (159, 175, 'OTHER_PERSON'), (184, 196, 'PETITIONER'), (265, 290, 'ORG'), (308, 316, 'DATE')]
# ['Under', 'the', 'aforesaid', 'deed,', 'which', 'has', 'come', 'into', 'existence', 'on', '30.06.1985,', 'three', 'partners,', 'viz.', 'Sri.Sampathlal', 'Jain,', 'W/o.Ratanlal', 'Jain', '(late),', 'Smt.Neena', 'Jain,', 'W/o.Jayanthilal', 'Jain', 'and', 'Smt.Lalitha', 'Jain', '(revision', 'petitioner)', 'alone', 'had', 'retired', 'from', 'the', 'partnership,', 'viz.,', 'M/s.Jayanthilal', '&', 'Company', 'with', 'effect', 'from', '1.7.1985.']
# 10 11
# 15 16
# 17 18
# 20 21
# 22 23
# 25 26
# 35 38
# 41 42
# [(6, 34, 'PRECEDENT'), (42, 55, 'JUDGE')]
# ['(vide', 'T.Fenn', 'Walter', 'v.', "Hon'ble", 'Mr.Justice', 'E.Padmanabhan,', '2002(3)', 'CTC', '321)', '19.']
# 1 6
# 6 7
# []
# ['There', 'was', 'no', 'attempt', 'on', 'his', 'part', 'to', 'Judge', 'whether', 'the', 'proved', 'facts', 'were', 'consistent', 'with', 'the', 'innocence', 'of', 'the', 'accused', 'persons.']
# [(171, 190, 'PROVISION')]
# ['But', 'it', 'would', 'not', 'be', 'correct', 'to', 'assume', 'that', 'every', 'minor', 'infraction', 'of', 'public', 'duty', 'by', 'every', 'public', 'officer', 'would', 'commend', 'the', 'Court', 'to', 'grant', 'compensation', 'in', 'a', 'petition', 'under', 'Articles', '226', 'and', '32', 'by', 'applying', 'the', 'principle', 'of', 'public', 'law', 'proceeding.']
# 30 34
# [(123, 134, 'PROVISION'), (142, 165, 'STATUTE'), (176, 186, 'PROVISION'), (194, 217, 'STATUTE')]
# ['The', 'brief', 'facts', 'of', 'this', 'case', 'are', 'that', 'the', 'accused', 'persons', 'have', 'been', 'charge', 'sheeted', 'for', 'committing', 'offence', 'punishable', 'under', 'Section', '407', 'of', 'The', 'Indian', 'Penal', 'Code,', '1860', 'read', 'with', 'Section', '34', 'of', 'The', 'Indian', 'Penal', 'Code,', '1860.']
# 20 22
# 24 28
# 30 32
# 34 38
# [(103, 107, 'OTHER_PERSON')]
# ['In', 'view', 'of', 'the', 'injuries', 'sustained', 'has', 'been', 'questioned', 'by', 'learned', 'counsel', 'for', 'the', 'appellant', 'on', 'basis', 'of', "Modi's", 'Medical', 'Jurisprudence', 'and', 'Toxicology,', 'Twenty-third', 'Edition,', '815', 'wherein', 'towards', 'end', 'it', 'has', 'been', 'stated:-']
# 18 19
# [(31, 71, 'CASE_NUMBER'), (114, 154, 'CASE_NUMBER')]
# ['Thereupon,', 'the', 'appellant', 'filed', 'Writ', 'Petitions', 'Nos.', '3352', 'to', '3357', 'of', '1969', 'raising', 'the', 'same', 'grounds', 'as', 'were', 'urged', 'in', 'Writ', 'Petitions', 'Nos,', '1557', 'to', '1559', 'of', '1969.']
# 4 12
# 20 28
# [(186, 196, 'PROVISION'), (204, 225, 'STATUTE')]
# ['The', 'second', 'question,', 'which', 'is', 'relevant', 'for', 'the', 'present', 'purposes,', 'considered', 'by', 'the', 'majority', 'is,', 'whether', 'the', 'said', 'Corporations', 'can', 'be', 'said', 'to', 'be', '"other', 'authorities"', 'within', 'the', 'meaning', 'of', 'Article', '12', 'of', 'the', 'Constitution', 'of', 'India.']
# 30 32
# 34 37
# [(29, 35, 'OTHER_PERSON')]
# ['It', 'is', 'then', 'contended', 'by', 'Shri', 'Parekh', 'that', 'the', 'appellant-Institution', 'is', 'running', 'an', 'educational', 'institution', 'and', 'intends', 'to', 'establish', 'a', 'public', 'school', 'and', 'that', 'since', 'other', 'land', 'was', 'available,', 'the', 'Government', 'would', 'have', 'acquired', 'some', 'other', 'land', 'leaving', 'the', 'acquired', 'land', 'for', 'the', 'appellant.']
# 6 7
# [(136, 145, 'OTHER_PERSON')]
# ['The', 'learned', 'Subordinate', 'Judge', 'found', 'that', 'the', 'launch', 'was', 'in', 'a', 'very', 'poor', 'condition', 'prior', 'to', 'collision', 'and', 'he', 'accepted', 'the', 'evidence', 'of', 'Mr.', 'Patterson,', 'who', 'is', 'a', 'marine', 'surveyor,', 'that', 'the', 'pre-collision', 'value', 'of', 'the', 'launch', 'was', 'Rs.', '5,000/-.']
# 24 25
# [(26, 34, 'OTHER_PERSON'), (39, 48, 'OTHER_PERSON')]
# ['He', 'further', 'disclosed', 'that', 'Surender', 'and', 'Raj', 'Kumar', 'were', 'the', 'persons', 'who', 'had', 'run', 'away', 'after', 'alighting', 'from', 'the', 'motor-cycle.']
# 4 5
# 6 8
# [(12, 17, 'GPE'), (53, 84, 'ORG'), (182, 207, 'ORG')]
# ['The', 'sale', 'in', 'India', 'have', 'been', 'made', 'to', 'the', 'distributors', 'Supreme', 'Hi-Fidelity', '(P)', 'Limited,', 'who', 'continued', 'to', 'be', 'in', 'operation', 'till', 'a', 'recent', 'date', 'under', 'a', 'separate', 'agreement', 'between', 'them', 'and', 'Alpine', 'Electronics,', 'Japan.']
# 3 4
# 10 14
# 31 34
# []
# ['In', 'so', 'far', 'as', 'the', 'valuation', 'of', 'the', 'land', 'is', 'concerned,', 'the', 'concerned', 'revenue', 'authorities', 'have', 'bestowed', 'their', 'consideration', 'on', 'the', 'basis', 'of', 'sale', 'deeds', 'executed', 'and', 'the', 'prevalent', 'area', 'rates', 'to', 'say', 'that', 'both', 'the', 'lands', 'are', 'almost', 'identically', 'valued.']
# [(4, 10, 'OTHER_PERSON'), (64, 84, 'CASE_NUMBER'), (86, 106, 'CASE_NUMBER'), (115, 144, 'CASE_NUMBER')]
# ['Mr.', 'Kapoor', 'drew', 'our', 'attention', 'to', 'the', 'prayers', 'of', 'the', 'petition', 'in', 'G.A.', 'No.3390', 'of', '2007,', 'G.A.', 'No.1311', 'of', '2008', 'and', 'the', 'Execution', 'Case', 'No.126', 'of', '2008', 'and', 'submitted', 'that', 'in', 'these', 'three', 'pending', 'applications', 'would', 'show', 'that', 'the', 'plaintiff/respondent', 'No.1', 'had', 'not', 'changed', 'his', 'stand', 'following', 'the', 'compromise', 'decree', 'in', 'any', 'manner', 'whatsoever.']
# 1 2
# 12 16
# 16 20
# 22 27
# [(25, 35, 'COURT'), (44, 65, 'ORG')]
# ['In', 'this', 'regard,', 'what', 'the', 'Apex', 'Court', 'held', 'in', 'N.K.V.Bros.', '(P.)', 'Ltd.', '(supra)', 'needs', 'to', 'be', 'cited:-', '"3.']
# 5 7
# 9 12
# [(17, 25, 'RESPONDENT')]
# ['In', 'the', 'year', '1962', 'Hindalco,', 'respondent', 'No.', '2,', 'started', 'production', 'of', 'aluminium.']
# 4 5
# [(142, 156, 'GPE')]
# ['All', 'that', 'was', 'shown', 'was', 'that', 'the', 'shoes', 'bearing', 'that', 'mark', 'were', 'advertised', 'in', 'some', 'of', 'the', 'American', 'periodicals', 'which', 'had', 'some', 'circulation', 'in', 'the', 'United', 'Kingdom.']
# 25 27
# [(5, 10, 'OTHER_PERSON')]
# ['Shri', "Gupta's", 'plea', 'of', 'hardship', 'and', 'inconvenience', 'to', 'the', 'landlord', 'does', 'at', 'first', 'arouse', 'a', 'feeling', 'of', 'sympathy', 'but', 'on', 'a', 'little', 'reflection', 'it', 'vanishes.']
# 1 2
# []
# ['That,', 'in', 'my', 'opinion,', 'has', 'no', 'application.']
# []
# ['The', 'authority', 'must', 'not', 'act', 'as', 'a', 'mere', 'tax', 'gatherer', 'by', 'any', 'means.']
# [(145, 158, 'OTHER_PERSON')]
# ['No', 'counter-affidavit', 'has', 'been', 'filed', 'by', 'the', 'State', 'but', 'nonetheless', 'written', 'arguments', 'have', 'been', 'filed', 'by', 'the', "petitioners'", 'counsel', 'as', 'well', 'as', 'by', 'Sri', 'Vishnu', 'Pratap,', 'standing', 'counsel.']
# 24 26
# []
# ['The', 'learned', 'Solicitor-General', 'had', 'submitted', 'that', 'increase', 'in', 'tariff', 'was', 'necessitated', 'because', 'of', 'rise', 'in', 'prices.']
# [(127, 138, 'PROVISION'), (142, 145, 'STATUTE')]
# ['The', 'act', 'of', 'the', 'respondent', 'was', 'not', 'only', 'immensely', 'dangerous', 'but', 'cruel', 'and', 'callus', 'also', 'and', 'this', 'act', 'constitutes', 'an', 'offence', 'under', 'Section', '304', 'of', 'IPC.']
# 22 24
# 25 26
# [(12, 17, 'GPE')]
# ['Besides,', 'if', 'India', 'is', 'to', 'be', 'regarded', 'as', 'one', 'economic', 'unit', 'there', 'can', 'be', 'no', 'objection', 'to', 'a', 'consumer', 'in', 'one', 'State', 'getting', 'goods', 'cheaply', 'from', 'a', 'neighbouring', 'State.']
# 2 3
# []
# ['Bearing', 'in', 'mind', 'the', 'essential', 'features', 'of', 'the', 'offence', 'of', 'criminal', 'conspiracy,', 'enumerated', 'above,', 'we', 'may', 'advert', 'to', 'the', 'facts', 'of', 'the', 'instant', 'case.']
# []
# ['Thus', 'in', 'the', 'absence', 'of', 'any', 'material', 'on', 'record', 'to', 'show', 'that', 'this', 'commission', 'was', 'paid', 'for', 'securing', 'acceptance', 'of', 'tender,', 'we', 'see', 'no', 'good', 'reason', 'to', 'disallow', 'this', 'item.']
# []
# ['I', 'do', 'not', 'think', 'it', 'fit', 'to', 'grant', 'leave', 'raised.']
# [(64, 73, 'ORG'), (79, 84, 'GPE'), (162, 180, 'ORG'), (234, 251, 'ORG')]
# ['After', 'the', 'incorporation', 'of', 'the', 'assessee', 'the', 'activities', 'of', 'the', 'Swiss', 'Co.', 'in', 'India', 'were', 'bifurcated', ':', 'the', 'pharmaceutical', 'section', 'was', 'taken', 'over', 'by', 'the', 'assessee', 'Ciba', 'of', 'India', 'Ltd.', 'and', 'the', 'other', 'lines', 'of', 'business', 'were', 'continued', 'by', 'Ciba', '(India)', 'Ltd.']
# 10 12
# 13 14
# 26 30
# 39 42
# [(242, 275, 'PROVISION'), (283, 295, 'STATUTE')]
# ['In', 'the', 'absence', 'of', 'necessary', 'facts', 'and', 'figures', 'it', 'is', 'not', 'possible', 'to', 'accept', 'the', 'argument', 'of', 'the', 'learned', 'counsel', 'that', 'in', 'the', 'present', 'case', 'the', 'incidence', 'of', 'taxation', 'is', 'so', 'high', 'as', 'to', 'amount', 'to', 'unreasonabe', 'restrictions', 'on', 'the', 'rights', 'guaranteed', 'by', 'Article', '19(1)', 'clauses', '(f)', 'and', '(g)', 'of', 'the', 'Constitution.']
# 43 49
# 51 52
# [(24, 40, 'ORG'), (42, 52, 'GPE'), (54, 60, 'GPE')]
# ['The', 'petitioner,', 'Messrs.', 'Kanpur', 'Oil', 'Mills,', 'Harrisganj,', 'Kanpur,', 'is', 'a', 'firm', 'carrying', 'on', 'the', 'business', 'of', 'manufacturing', 'oils', 'and', 'dealing', 'in', 'them.']
# 3 6
# 6 7
# 7 8
# []
# ['The', 'counsel', 'argued', 'that', 'since', 'the', 'applicants', 'have', 'surrendered', 'that', 'the', 'cost', 'be', 'removed.']
# [(268, 286, 'PROVISION'), (294, 302, 'STATUTE')]
# ['So', 'far', 'as', 'accused', 'No.', '8', 'is', 'concerned,', 'we', 'have', 'heard', 'the', 'learned', 'Counsel', 'for', 'the', 'accused', 'on', 'the', 'point', 'of', 'sentence,', 'and', 'no', 'special', 'circumstances', 'have', 'been', 'made', 'out', 'so', 'as', 'to', 'award', 'him', 'the', 'sentence', 'of', 'less', 'than', 'one', 'year', 'for', 'the', 'offence', 'held', 'to', 'be', 'proved', 'against', 'him', 'under', 'Section', '25(1-B)(a)', 'of', 'the', 'Arms', 'Act.']
# 52 54
# 56 58
# [(215, 229, 'OTHER_PERSON'), (233, 238, 'GPE')]
# ['In', 'the', 'circumstances,', 'we', 'find', 'that', 'he', 'has', 'engaged', 'himself', 'both', 'in', 'abetting', 'smuggling', 'of', 'goods,', 'as', 'has', 'been', 'found', 'in', 'the', 'order', 'of', 'detention,', 'and', 'he', 'has', 'also', 'been', 'dealing', 'in', 'the', 'contraband', 'Smuggled', 'goods', 'on', 'behalf', 'of', 'Dawood', 'Ibrahim', 'in', 'India.']
# 39 41
# 42 43
# [(55, 140, 'PRECEDENT'), (153, 162, 'DATE')]
# ['The', 'said', 'argument', 'was', 'repelled', 'in', 'the', 'said', 'decision', 'of', 'C.B.I.,', 'New', 'Delhi', 'Vs.', 'Dinesh', 'Kumar', 'Singh,', 'Crl.', 'Misc.', 'Bail', 'Cancellation', 'No.216', 'of', '2014,', 'decided', 'on', '15.7.2014', 'in', 'the', 'following', 'manner', ':-']
# 10 24
# 26 27
# [(42, 49, 'OTHER_PERSON'), (70, 81, 'OTHER_PERSON'), (109, 116, 'OTHER_PERSON')]
# ['He', 'was', 'then', 'succeeded', 'as', 'President', 'by', 'Mr.', 'Barucha', '&', 'a', 'new', 'member,', 'Mr.', 'E.', 'M.', 'Joshi,', 'was', 'appointed', 'to', 'take', 'Mr.', "Barucha's", 'plane.']
# 8 9
# 14 17
# 22 23
# [(52, 61, 'DATE'), (132, 145, 'PROVISION'), (153, 159, 'STATUTE')]
# ['By', 'virtue', 'of', 'the', 'same,', 'it', 'was', 'made', 'mandatory,', 'after', '1.10.2015', 'for', 'every', 'transport', 'vehicle,', 'notified', 'by', 'the', 'Central', 'Government', 'under', 'Section', '41(4)', 'of', 'the', 'MV', 'Act,', 'to', 'be', 'equipped', 'or', 'fitted', 'with', 'a', 'speed', 'governor', 'by', 'the', 'manufacturer', 'of', 'the', 'vehicle,', 'having', 'a', 'pre-set', 'speed', 'limit', 'of', '80', 'kmph,', 'conforming', 'to', 'the', 'Standard', 'AIS', '018/', '2001.']
# 10 11
# 21 23
# 25 27
# [(0, 23, 'WITNESS'), (94, 104, 'OTHER_PERSON'), (134, 143, 'GPE')]
# ['Adhip', 'Ohandra', 'Mukherjee,', 'p.w.', '6', 'who', 'was', 'the', 'Director', 'of', 'operation', 'of', 'the', 'State', 'Transport', 'and,', 'S.K.', 'Dutta,', 'the', 'Chief', 'Accountant', 'of', 'the', 'Belgharia', 'Office,', 'then', 'went', 'to', 'the', 'Mission', 'Row', 'Office', 'for', 'making', 'enquiries.']
# 0 3
# 16 18
# 23 24
# [(16, 30, 'RESPONDENT')]
# ['Respondent', 'no.1-Sweety', 'Kothari', 'had', 'filed', 'an', 'application', 'seeking', 'following', 'information:', '―', '(a)', 'Copies', 'of', 'the', 'advertisements', 'calling', 'for', 'applications', 'for', 'selection', 'of', 'ITAT', 'members', 'in', 'Calendar', 'Years', '2002', 'and', '2003.']
# 2 3
# [(105, 134, 'COURT')]
# ['We', 'observe', 'that', 'the', 'questions', 'of', 'law', 'as', 'framed', 'are', 'not', 'happily', 'worded', 'in', 'the', 'context', 'of', 'the', 'order', 'of', 'the', 'Income-tax', 'Appellate', 'Tribunal', 'which', 'we', 'have', 'extracted', 'elsewhere', 'in', 'this', 'judgment.']
# 21 24
# [(6, 16, 'WITNESS'), (98, 108, 'GPE'), (110, 119, 'GPE'), (168, 178, 'WITNESS')]
# ['P.W.1-Basavaraju', 'has', 'stated', 'that', 'in', 'the', 'year', '2010', 'he', 'was', 'residing', 'at', 'house', 'No.18,', 'Muthappa', 'Block,', 'Ganganagar,', 'Bengaluru', 'and', 'the', 'said', 'house', 'belongs', 'to', 'his', 'brother', 'P.W.2-B.Puttappa.']
# 1 1
# 16 17
# 17 18
# 27 27
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 32
#      30 print(start_idx,end_idx)
#      31 if start_idx == end_idx:
# ---> 32     labels[start_idx] = 'B_' + label
#      33 else:
#      34     labels[start_idx] = 'B_' + label
#
# IndexError: list assignment index out of range

# %%
def custom_word_tokenize(text):
    # Simple tokenization using regex (you can replace this with your custom tokenizer)
    return re.findall(r'\b\w+\b', text)

def bio_encode_words(text, annotations):
    words = custom_word_tokenize(text)
    bio_dict = {word: 'O' for word in words}

    for annotation_entry in annotations:
        for annotation in annotation_entry["result"]:
            start = annotation["value"]["start"]
            end = annotation["value"]["end"]
            label = annotation["value"]["labels"][0]

            start_word = len(custom_word_tokenize(text[:start]))
            end_word = start_word + len(custom_word_tokenize(text[start:end]))

            bio_dict[words[start_word]] = 'B_' + label
            for i in range(start_word + 1, end_word):
                bio_dict[words[i]] = 'I_' + label

    return bio_dict

# %%
! pip install nltk
